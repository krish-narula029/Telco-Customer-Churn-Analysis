# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\monga\Downloads\Raw Project (2)\telco_data.csv")

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            6293 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           6043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            4543 non-null   float64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   6043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       5543 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# customerID             0
# gender               750
# SeniorCitizen          0
# Partner             1000
# Dependents             0
# tenure              2500
# PhoneService           0
# MultipleLines          0
# InternetService     1000
# OnlineSecurity         0
# OnlineBackup           0
# DeviceProtection       0
# TechSupport            0
# StreamingTV         1500
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges      1500
# TotalCharges           0
# Churn                  0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No     1.0           No
# 1  5575-GNVDE    Male              0      No         No    34.0          Yes
# 2  3668-QPYBK    Male              0      No         No     2.0          Yes
# 3  7795-CFOCW    Male              0      No         No    45.0           No
# 4  9237-HQITU  Female              0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isna().sum()
# Out:
# customerID             0
# gender               750
# SeniorCitizen          0
# Partner             1000
# Dependents             0
# tenure              2500
# PhoneService           0
# MultipleLines          0
# InternetService     1000
# OnlineSecurity         0
# OnlineBackup           0
# DeviceProtection       0
# TechSupport            0
# StreamingTV         1500
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges      1500
# TotalCharges           0
# Churn                  0
# dtype: int64

# %%
df.isna().sum(axis = 1).value_counts().sort_index()
# Out:
# 0    4543
# 1    1000
# 3     500
# 5     250
# 6     750
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure              float64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
for col in ["gender", "Partner", "InternetService", "StreamingTV", "Churn"]:
    print("\n", col)
    print(df[col].value_counts(dropna=False))
# Out:
#  gender
# gender
# Male      3202
# Female    3091
# NaN        750
# Name: count, dtype: int64
#
#  Partner
# Partner
# No     3115
# Yes    2928
# NaN    1000
# Name: count, dtype: int64
#
#  InternetService
# InternetService
# Fiber optic    2660
# DSL            2082
# No             1301
# NaN            1000
# Name: count, dtype: int64
#
#  StreamingTV
# StreamingTV
# No                     2199
# Yes                    2146
# NaN                    1500
# No internet service    1198
# Name: count, dtype: int64
#
#  Churn
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# customerID             0
# gender               750
# SeniorCitizen          0
# Partner             1000
# Dependents             0
# tenure              2500
# PhoneService           0
# MultipleLines          0
# InternetService     1000
# OnlineSecurity         0
# OnlineBackup           0
# DeviceProtection       0
# TechSupport            0
# StreamingTV         1500
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges      1500
# TotalCharges           0
# Churn                  0
# dtype: int64

# %%
missing = df.isna().sum()
missing[missing > 0 ]
# Out:
# gender              750
# Partner            1000
# tenure             2500
# InternetService    1000
# StreamingTV        1500
# MonthlyCharges     1500
# dtype: int64

# %%
missing_pct = (df.isna().sum() / len(df) * 100).round(2)
missing_pct[missing_pct > 0]
# Out:
# gender             10.65
# Partner            14.20
# tenure             35.50
# InternetService    14.20
# StreamingTV        21.30
# MonthlyCharges     21.30
# dtype: float64

# %%
df[["tenure", "MonthlyCharges"]].describe()
# Out:
#             tenure  MonthlyCharges
# count  4543.000000     5543.000000
# mean     32.546555       64.876403
# std      24.505519       30.101331
# min       0.000000       18.250000
# 25%       9.000000       35.750000
# 50%      29.000000       70.550000
# 75%      56.000000       89.925000
# max      72.000000      118.600000

# %%
df["tenure"] = df["tenure"].fillna(df["tenure"].median())
df["MonthlyCharges"] = df["MonthlyCharges"].fillna(df["MonthlyCharges"].median())

# %%
df.isna().sum()
# Out:
# customerID             0
# gender               750
# SeniorCitizen          0
# Partner             1000
# Dependents             0
# tenure                 0
# PhoneService           0
# MultipleLines          0
# InternetService     1000
# OnlineSecurity         0
# OnlineBackup           0
# DeviceProtection       0
# TechSupport            0
# StreamingTV         1500
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# Churn                  0
# dtype: int64

# %%
for col in ["gender", "Partner", "InternetService", "StreamingTV"]:
    print("\n", col)
    print(df[col].value_counts(dropna=False))
# Out:
#  gender
# gender
# Male      3202
# Female    3091
# NaN        750
# Name: count, dtype: int64
#
#  Partner
# Partner
# No     3115
# Yes    2928
# NaN    1000
# Name: count, dtype: int64
#
#  InternetService
# InternetService
# Fiber optic    2660
# DSL            2082
# No             1301
# NaN            1000
# Name: count, dtype: int64
#
#  StreamingTV
# StreamingTV
# No                     2199
# Yes                    2146
# NaN                    1500
# No internet service    1198
# Name: count, dtype: int64

# %%
for col in ["gender", "Partner", "InternetService", "StreamingTV"]:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize = True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure              float64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors = "coerce")

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"] = df["TotalCharges"].fillna(df["TotalCharges"].median())

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
for col in ["Contract", "InternetService", "PaymentMethod"]:
    print("\n", col)
    print(pd.crosstab(df[col], df["Churn"], normalize = "index") * 100)
# Out:
#  Contract
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858
#
#  InternetService
# Churn                   No        Yes
# InternetService
# DSL              80.739673  19.260327
# Fiber optic      62.595628  37.404372
# No               92.390469   7.609531
#
#  PaymentMethod
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %%
pd.crosstab(
    pd.cut(df["tenure"], bins = [0,12,24,48,72]),
    df["Churn"],
    normalize = "index") * 100
# Out:
# Churn            No        Yes
# tenure
# (0, 12]   53.156385  46.843615
# (12, 24]  73.879444  26.120556
# (24, 48]  74.640744  25.359256
# (48, 72]  89.826990  10.173010

# %%
pd.crosstab(
    pd.cut(df["MonthlyCharges"], bins = 4),
    df["Churn"],
    normalize = "index") * 100
# Out:
# Churn                    No        Yes
# MonthlyCharges
# (18.15, 43.338]   87.224080  12.775920
# (43.338, 68.425]  78.457197  21.542803
# (68.425, 93.512]  68.422646  31.577354
# (93.512, 118.6]   65.651438  34.348562

# %%
df.groupby("Churn")[["tenure", "MonthlyCharges", "TotalCharges"]].mean()
# Out:
#           tenure  MonthlyCharges  TotalCharges
# Churn
# No     34.483765       63.381591   2552.882494
# Yes    22.439807       73.567978   1531.796094

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data = df, x = "Churn")
plt.title("Customer Churn Distribution")
plt.show()

# %%
sns.countplot(data = df, x = "Contract", hue = "Churn")
plt.title("Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")
plt.show()

# %%
sns.countplot(data = df, x = "InternetService", hue = "Churn")
plt.title("Churn by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Number of Customers")
plt.show()

# %%
sns.countplot(data = df, x = "PaymentMethod", hue = "Churn")
plt.title("Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")
plt.xticks(rotation = 45)
plt.show()

# %%
sns.boxplot(data = df, x = "Churn", y = "tenure")
plt.title("Tenure vs Churn")
plt.xlabel("Churn")
plt.ylabel("Tenure (months)")
plt.show()

# %%
sns.boxplot(data = df, x = "Churn", y = "MonthlyCharges")
plt.title("MonthlyCharges vs Churn")
plt.xlabel("Churn")
plt.ylabel("MonthlyCharges")
plt.show()

# %%
sns.boxplot(data = df, x = "Churn", y = "TotalCharges")
plt.title("TotalCharges vs Churn")
plt.xlabel("Churn")
plt.ylabel("Total Charges")
plt.show()

# %%
df[["SeniorCitizen", "tenure","MonthlyCharges", "TotalCharges"]].corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.004008        0.192526      0.102652
# tenure               0.004008  1.000000        0.221251      0.661536
# MonthlyCharges       0.192526  0.221251        1.000000      0.575482
# TotalCharges         0.102652  0.661536        0.575482      1.000000

# %%
plt.figure(figsize = (8,5))
sns.heatmap(
    df[["SeniorCitizen","tenure","MonthlyCharges", "TotalCharges"]].corr(),annot = True, cmap = "coolwarm",fmt = ".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df["Churn"] = df["Churn"].map({"No":0, "Yes" : 1})
df["Churn"].value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
pd.crosstab(
    df["Contract"],
    df["Churn"],
    normalize = "index"
)*100
# Out:
# Churn                   0          1
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
sns.countplot(data = df, x = "Contract", hue = "Churn")
plt.title("Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Customer Count")
plt.show()

# %%
pd.crosstab(
    df["PaymentMethod"],
    df["Churn"],
    normalize = "index"
) * 100
# Out:
# Churn                              0          1
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %%
sns.countplot(data = df, x ="PaymentMethod", hue = "Churn")
plt.title("Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Customer Count")
plt.xticks(rotation = 45)
plt.show()

# %%
pd.crosstab(df["InternetService"],df["Churn"],normalize = "index") * 100
# Out:
# Churn                    0          1
# InternetService
# DSL              80.739673  19.260327
# Fiber optic      62.595628  37.404372
# No               92.390469   7.609531

# %%
sns.countplot(data = df, x ="InternetService", hue = "Churn")
plt.title("Churn by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Customer Count")
plt.show()

# %%
pd.crosstab(df["SeniorCitizen"],df["Churn"],normalize = "index") * 100
# Out:
# Churn                  0          1
# SeniorCitizen
# 0              76.393832  23.606168
# 1              58.318739  41.681261

# %%
sns.countplot(data = df, x ="SeniorCitizen", hue = "Churn")
plt.title("Churn by Senior Citizen")
plt.xlabel("SeniorCitizen(0 = No, 1 = Yes)")
plt.ylabel("Customer Count")
plt.show()

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   float64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
x = df.drop(columns = ["customerID", "Churn"])
y = df["Churn"]
print("x shape:", x.shape)
print("y shape:", y.shape)
# Out:
# x shape: (7043, 19)
# y shape: (7043,)

# %%
import pandas as pd
x_encoded = pd.get_dummies(x, drop_first = True)
print("Encoded X shape:", x_encoded.shape)
print(x_encoded.head())
# Out:
# Encoded X shape: (7043, 30)
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0     1.0           29.85         29.85        False
# 1              0    34.0           56.95       1889.50         True
# 2              0     2.0           53.85        108.15         True
# 3              0    45.0           42.30       1840.75         True
# 4              0     2.0           70.70        151.65        False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
# 3        False           False             False
# 4        False           False              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                            True              False  ...
# 1                           False              False  ...
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x_encoded,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (5634, 30)
# X_test: (1409, 30)
# y_train: (5634,)
# y_test: (1409,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
print("X_train_scaled:", X_train_scaled.shape)
print("X_test_scaled:", X_test_scaled.shape)
# Out:
# X_train_scaled: (5634, 30)
# X_test_scaled: (1409, 30)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter = 1000)
model.fit(X_train_scaled,y_train)
print("Model Trained Successfully!")
# Out:
# Model Trained Successfully!

# %%
y_pred = model.predict(X_test_scaled)
print(y_pred[:10])
# Out:
# ['No' 'Yes' 'No' 'No' 'No' 'Yes' 'No' 'No' 'No' 'No']

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7906316536550745
#
# Confusion Matrix:
# [[923 112]
#  [183 191]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.83      0.89      0.86      1035
#          Yes       0.63      0.51      0.56       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.70      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize = (6,4))
sns.heatmap(cm, annot = True, fmt='d', cmap = 'Blues',
            xticklabels = ['No Churn', 'Churn'],
            yticklabels = ['No Churn', 'Churn'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix')
plt.show()

# %%
feature_importance = pd.DataFrame({
    'Feature': x_encoded.columns,
    'Coefficient': model.coef_[0]})

feature_importance['Abs_Coefficient'] = abs(
    feature_importance['Coefficient'])

feature_importance = feature_importance.sort_values(
    'Abs_Coefficient',
    ascending=False)

print(feature_importance.head(10))
# Out:
#                            Feature  Coefficient  Abs_Coefficient
# 25               Contract_Two year    -0.714293         0.714293
# 3                     TotalCharges    -0.540998         0.540998
# 10     InternetService_Fiber optic     0.374074         0.374074
# 11              InternetService_No     0.373741         0.373741
# 24               Contract_One year    -0.357482         0.357482
# 28  PaymentMethod_Electronic check     0.213944         0.213944
# 13              OnlineSecurity_Yes    -0.212555         0.212555
# 26            PaperlessBilling_Yes     0.183105         0.183105
# 19                 TechSupport_Yes    -0.167943         0.167943
# 23             StreamingMovies_Yes     0.167937         0.167937

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=feature_importance.head(10),
    x='Coefficient',
    y='Feature'
)
plt.title('Top 10 Features Influencing Churn')
plt.show()

# %%
print("Business Insights:")
print("1. Customers with shorter contracts are more likely to churn.")
print("2. Higher monthly charges are associated with higher churn risk.")
print("3. Fiber optic customers show relatively higher churn tendency.")
print("4. Customers with longer-term contracts are less likely to churn.")
print("5. The company should focus on high-risk customers with short contracts and high monthly charges.")
# Out:
# Business Insights:
# 1. Customers with shorter contracts are more likely to churn.
# 2. Higher monthly charges are associated with higher churn risk.
# 3. Fiber optic customers show relatively higher churn tendency.
# 4. Customers with longer-term contracts are less likely to churn.
# 5. The company should focus on high-risk customers with short contracts and high monthly charges.

# %%
df.to_csv("telco_final.csv", index = False)
print("CSV file saved successfully")
# Out:
# CSV file saved successfully

# %%
import os 
print(os.path.abspath("telco_final.csv"))
# Out:
# C:\Users\monga\Downloads\Telco Data\telco_final.csv
